# %% [markdown]
# <div class="alert alert-success"><div class='alert btn-success'>
# Марк, 😊буду рада, если смогла быть тебе полезной!)<br>
# Критичных ошибок нет. Молодец!)<br>
# С удовольствием принимаю проект!<br>
# Очень рекомендую посмотреть видео от Глеба Михайлова!)
# </div></div>
#
# Просто о сложном:<br>
# **[Линейная Регрессия для Дата Саентиста](https://www.youtube.com/watch?v=QZJ94igWVxQ&t=19s)**     <br>
#
#
# <br>
# <div class="alert alert-success"><div class='alert btn-success'>
# Надеюсь, ты найдешь для себя что-то интересное и полезное😊  <br>
# Желаю тебе удачи в дальнейшей учебе! 😉 </div></div>

# %% [markdown]
# Марк, привет! Меня зовут Ирина Литвинова. Сегодня я проверю твой проект.<br>
# <br> Ты можешь обращаться ко мне на "ты"😏 Надеюсь, ты не будешь против, если и я буду обращаться к тебе на "ты". Но если для тебя это неприемлeмо, дай знать, пожалуйста) <br>
# <br> Мне очень важна твоя реакция на мои комментарии, особенно <font color='red'>красные</font>. Можешь реагировать, например, так ('исправлено', ...)<br>
# <br> Ты можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. <br>
# Это нужно, чтобы не создавалась путаница😉<br>
# Например, так:<br>
#
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Были внесены следующие изменения ...<br></div>
#
#
# <br> Пожалуйста, не удаляй мои комментарии, так как они повышают качество повторного ревью и делают его быстрее)<br>
# <br> Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓<br>
#
# Для твоего удобства мои комментарии будут в <font color='green'>зеленой</font>, <font color='orange'>желтой</font> или <font color='red'>красной</font> рамках:<br>
# <br>
#
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <b>Ошибка:</b><br>
# Если требуются исправления. Работа не может быть принята с красными комментариями.<br></div>
#
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Если можно немного улучшить.<br></div>
#
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# Если все сделано отлично.<br></div>

# %% [markdown]
# # Выбор локации для скважины

# %% [markdown]
# Допустим, вы работаете в добывающей компании «ГлавРосГосНефть». Нужно решить, где бурить новую скважину.
#
# Вам предоставлены пробы нефти в трёх регионах: в каждом 10 000 месторождений, где измерили качество нефти и объём её запасов. Постройте модель машинного обучения, которая поможет определить регион, где добыча принесёт наибольшую прибыль. Проанализируйте возможную прибыль и риски техникой *Bootstrap.*
#
# Шаги для выбора локации:
#
# - В избранном регионе ищут месторождения, для каждого определяют значения признаков;
# - Строят модель и оценивают объём запасов;
# - Выбирают месторождения с самым высокими оценками значений. Количество месторождений зависит от бюджета компании и стоимости разработки одной скважины;
# - Прибыль равна суммарной прибыли отобранных месторождений.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# 👍 Есть введение в проект. Отлично!<br>
#
# </div>

# %% [markdown]
# ## Загрузка и подготовка данных

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Марк, у тебя ячейки начинались не с первой. Я проверила - код работает. Но лучше перед отправкой проекта проверять работоспособность кода - это можно сделать, нажав на панели Jupiter Hub 👉 **Kernel** 👉  **Restart & Run All** .<br>
# Потом обязательно сохрани. Для этого сделай так: 👉  **File**  👉   **Save and Checkpoint** .
# Когда сохранишь, пожалуйста, проверь - обрати внимание на сообщение "**Последняя контрольная точка: несколько секунд назад
# (автосохранение)**" <br>
# </div>

# %% [markdown]
# ![2022-11-22_10-29-10.png](attachment:2022-11-22_10-29-10.png)

# %% [markdown]
# ![2022-06-25_09-17-28.png](attachment:2022-06-25_09-17-28.png)

# %% [markdown]
# ![2022-06-26_15-59-11.png](attachment:2022-06-26_15-59-11.png)

# %%
# Импортирование необходимых библиотек:
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from numpy.random import RandomState

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Константы помещены в переменные<br></div>

# %%
# Константы
BUDGET = 10e9
COUNT_OF_WELLS = 500
COUNT_OF_SELECTED_WELLS = 200

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Здорово, что импортируешь необходимые библиотеки в первой ячейке. Так сразу понятно какие используются библиотеки и можно легко настроить свое окружение при необходимости.
# </div>

# %%
# Зададим random_seed:
np.random.seed(12345)

# %%
# Чтение датасетов:
rg_1 = pd.read_csv('/datasets/geo_data_0.csv')
rg_2 = pd.read_csv('/datasets/geo_data_1.csv')
rg_3 = pd.read_csv('/datasets/geo_data_2.csv')

k = [rg_1, rg_2, rg_3]

# %%
# Информация о датасетах:
for i in k:
    print(i.info())
    print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# Как видно из информации о датасетах, все три датасета схожи по столбцам и кол-ву строк

# %%
# Проверка на дубликаты:
for i in k:
    print('Кол-во дубликатов:', rg_1.duplicated().sum())
    print(' ')
# Out:
# Кол-во дубликатов: 0
#
# Кол-во дубликатов: 0
#
# Кол-во дубликатов: 0

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Еще можно проверить дубликаты по `id`
#
# </div>

# %%
# Удилм столбец с id:
for i in k:
    del(i['id'])

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Хорошо, что удаляешь `id`, это неинформативный признак.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# * Чтобы лучше узнать данные, можно посмотреть распределение целевой переменной для каждого региона, т.е. построить гистограмму для `product`.
# * Еще важно уделять внимание мультиколлинеарности признаков в линейных моделях.<br>
# Мультиколлинеарность — явление, при котором наблюдается сильная корреляция между признаками, что может негативно отразиться на модели.<br>
#
# Рекомендую посмотреть отрывок из курса Статистики - ["Корреляция и регрессия".](https://stepik.org/lesson/8086/step/1?unit=1365) <br>
#
# </div>

# %%
# Разбьём данные на обучающую и валидационную выборки в соотношении 75:25.
rg_1_train, rg_1_valid = train_test_split(rg_1, test_size = .25)
rg_2_train, rg_2_valid = train_test_split(rg_2, test_size = .25)
rg_3_train, rg_3_valid = train_test_split(rg_3, test_size = .25)

# %%
# Проверим размеры полученных выборок:

for i, j in zip([rg_1_train, rg_2_train, rg_3_train], [rg_1_valid, rg_2_valid, rg_3_valid]):
    print(i.shape)
    print(j.shape)
    print(' ')
# Out:
# (75000, 4)
# (25000, 4)
#
# (75000, 4)
# (25000, 4)
#
# (75000, 4)
# (25000, 4)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Данные разделены на обучающую и валидационную выборку корректно - 75:25.<br>
# И проверены!)
# </div>

# %%
# Разделим выборки на features и target:
features_train_rg_1 = rg_1_train.drop(['product'], axis=1)
target_train_rg_1 = rg_1_train['product']

features_valid_rg_1 = rg_1_valid.drop(['product'], axis=1)
target_valid_rg_1 = rg_1_valid['product']

features_train_rg_2 = rg_2_train.drop(['product'], axis=1)
target_train_rg_2 = rg_2_train['product']

features_valid_rg_2 = rg_2_valid.drop(['product'], axis=1)
target_valid_rg_2 = rg_2_valid['product']

features_train_rg_3 = rg_3_train.drop(['product'], axis=1)
target_train_rg_3 = rg_3_train['product']

features_valid_rg_3 = rg_3_valid.drop(['product'], axis=1)
target_valid_rg_3 = rg_3_valid['product']

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Для каждого региона действия повторяются, в таких случаях удобно использовать функцию. Это позволит не писать один и тот же код несколько раз и избегать ошибок. В случае необходимых изменений, достаточно поправить функцию, а не вносить правки несколько раз.
# </div>

# %% [markdown]
# ## Обучение и проверка модели

# %%
# Масшабирование значений
scaler = StandardScaler()
scaler.fit(features_train_rg_1)
features_train_rg_1 = scaler.transform(features_train_rg_1)
features_valid_rg_1 = scaler.transform(features_valid_rg_1)

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Для `features_train_rg_1` можно использовать сразу `fit_transform()`. Она объединяет функции: `fit()` и `transform()`.
# </div>

# %%
# Модель для первого региона:
model_1 = LinearRegression()
model_1.fit(features_train_rg_1, target_train_rg_1)
predictions_1 = model_1.predict(features_valid_rg_1)
print('Средний запас предсказанного сырья:',predictions_1.mean())
print('RMSE',mean_squared_error(predictions_1, target_valid_rg_1)**0.5)
# Out:
# Средний запас предсказанного сырья: 92.59256778438035
# RMSE 37.5794217150813

# %% [markdown]
# В первом регионе модель ошиблась в среднем на 37.579 барлей нефти, что составляет примерно: 16.650.00р.

# %%
# Масшабирование значений
scaler = StandardScaler()
scaler.fit(features_train_rg_2)
features_train_rg_2 = scaler.transform(features_train_rg_2)
features_valid_rg_2 = scaler.transform(features_valid_rg_2)

# %%
# Модель для второго региона:
model_2 = LinearRegression()
model_2.fit(features_train_rg_2, target_train_rg_2)
predictions_2 = model_2.predict(features_valid_rg_2)
print('Средний запас предсказанного сырья:',predictions_2.mean())
print('RMSE',mean_squared_error(predictions_2, target_valid_rg_2)**0.5)
# Out:
# Средний запас предсказанного сырья: 68.76995145799754
# RMSE 0.889736773768065

# %% [markdown]
# Во втором регионе RMSE составляет 0.89, что эквивалентно 400.500р. Средний заработок: 30.915.000р.

# %%
# Масшабирование значений
scaler = StandardScaler()
scaler.fit(features_train_rg_3)
features_train_rg_3 = scaler.transform(features_train_rg_3)
features_valid_rg_3 = scaler.transform(features_valid_rg_3)

# %%
# Модель для третьего региона:
model_3 = LinearRegression()
model_3.fit(features_train_rg_3, target_train_rg_3)
predictions_3 = model_3.predict(features_valid_rg_3)
print('Средний запас предсказанного сырья:',predictions_3.mean())
print('RMSE',mean_squared_error(predictions_3, target_valid_rg_3)**0.5)
# Out:
# Средний запас предсказанного сырья: 95.087528122523
# RMSE 39.958042459521614

# %% [markdown]
# У третьего региона наибольший средний запас 95.087 тыс. барлей. Однако наблюдается и самое большое отклонение.

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Добавлены выводы по каждому региону с учётом размера RMSE<br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2 </b><br>
#
# Здесь еще стоит обратить внимание на размер ошибки, в двух регионах она катастрофически большая - до 40% от среднего запаса.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
#     Марк, все расчеты верные. Осталось добавить вывод :) Обрати внимание на размер ошибок (RMSE).   </s>
# </div>

# %% [markdown]
# ## Подготовка к расчёту прибыли

# %%
# Сохраним ключевые значения для расчётов в отдельных переменных
oil_volume_1 = predictions_1.mean()
oil_volume_2 = predictions_2.mean()
oil_volume_3 = predictions_3.mean()
oil_volume_list_1 = pd.Series(predictions_1)
oil_volume_list_2 = pd.Series(predictions_2)
oil_volume_list_3 = pd.Series(predictions_3)
RMSE_1 = mean_squared_error(predictions_1, target_valid_rg_1)
RMSE_2 = mean_squared_error(predictions_2, target_valid_rg_2)
RMSE_3 = mean_squared_error(predictions_3, target_valid_rg_3)

# %%
# Рассчитаем достаточный объём сырья для безубыточной разработки новой скважины:
enough_well_oil = (BUDGET / COUNT_OF_SELECTED_WELLS / 450000)
enough_well_oil
# Out:
# 111.11111111111111

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Достаточный объём сырья для безубыточной разработки новой скважины рассчитан верно.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Во всех расчётах числа заменены на переменные с константами<br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2 </b><br>
#
# Почти во всех:) Еще можно 450000 заменить )
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Марк, лучше не использовать в коде готовые числа (значения), а заменить их константами.<br>
# Например, BUDGET =  `10e9` <br>
#
# Представь, если ты решишь внести изменения, тебе надо будет каждое число искать в проекте и менять. <br>  </s>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# * Согласно руководству по написанию кода на Python [PEP-8](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html#section-29) названия констант принято задавать заглавными буквами, например, `BUDGET`. А еще важно объявлять их в начале проекта после импортов, затем загрузка данных. Так проще будет их найти и изменить, если возникнет такая необходимость.
# * Для записи больших чисел и более удобного чтения, чтобы не запутаться в нулях, можно использовать такую запись: `10_000_000_000` или `10e9`, что означает 10 * 10**9 .
# </div>

# %% [markdown]
# Получается, что для безубыточной разработки месторождения скважина должна принести не менее 112 тыс. баррелей

# %%
# Сравним со средними предсказаниями по участкам:
print(oil_volume_1)
print(oil_volume_2)
print(oil_volume_3)
# Out:
# 92.59256778438035
# 68.76995145799754
# 95.087528122523

# %%
print(rg_1['product'].mean())
print(rg_2['product'].mean())
print(rg_3['product'].mean())
# Out:
# 92.50000000000001
# 68.82500000000002
# 95.00000000000004

# %% [markdown]
# Как видно, средние каждой скважины всех трёх участков меньше, чем необходимый объём

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Добавлен расчёт среднего запаса для регионов по истинным данным<br></div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера V-2</b>
#
# <b>Совет:</b> <br>
# Здесь вот на что надо обратить внимание! <br>
# В каждом регионе средний объем сырья меньше достаточного объёма для безубыточности. <br>
#
# Средний объем предсказанного сырья рассчитан на основании 25 000 точек, из которых в результате надо выбрать 200. В результате,  среди этих скважин могут быть скважины с достаточным и недостаточным запасом сырья. <br>
#
# Имеено техника "Bootstrap" позволяет оценить риск убытков при случайным отборе точек. 1000 раз отбирая случайным образом точки, считаем какой % случаев принесет убытки.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Здесь надо рассчитать средний запас в каждом регионе (`rg_1['product'].mean()` и т.д.) и посмотреть превышает он 111 единиц или нет.</s>
# </div>

# %%
# Отберём по предсказаниям модели 200 скважин с лучшими показателями в каждом регионе:
good_well_1 = oil_volume_list_1.sort_values(ascending=False).head(COUNT_OF_SELECTED_WELLS)
good_well_2 = oil_volume_list_2.sort_values(ascending=False).head(COUNT_OF_SELECTED_WELLS)
good_well_3 = oil_volume_list_3.sort_values(ascending=False).head(COUNT_OF_SELECTED_WELLS)

# %%
# Рассчитаем средние для 200 лучших скважин каждого региона:
good_well_1_mean = good_well_1.mean()
good_well_2_mean = good_well_2.mean()
good_well_3_mean = good_well_3.mean()
print(good_well_1_mean)
print(good_well_2_mean)
print(good_well_3_mean)
# Out:
# 155.511654194057
# 138.74876816199424
# 149.13784819053984

# %% [markdown]
# ## Расчёт прибыли и рисков

# %%
# Напишем функцию расчёта прибыли по участку:
def profit_counter(predictions, target, count_of_good_wells = COUNT_OF_SELECTED_WELLS, barrel_price = 450000):
    target_good = pd.Series(target).sort_values(ascending=False).head(count_of_good_wells)
    predictions_good = pd.Series(predictions).sort_values(ascending=False).head(count_of_good_wells)
    return (predictions_good.sum() * barrel_price) - BUDGET, (target_good.sum() * barrel_price) - BUDGET

# %%
# Проведём расчёт прибыли с помощью функции profit_counter:
predicted_profit_rg_1, target_profit_rg_1 = profit_counter(predictions_1, target_valid_rg_1)
predicted_profit_rg_2, target_profit_rg_2 = profit_counter(predictions_2, target_valid_rg_2)
predicted_profit_rg_3, target_profit_rg_3 = profit_counter(predictions_3, target_valid_rg_3)
print('Предсказанная прибыль с первого участка',predicted_profit_rg_1)
print('Фактическая прибыль с первого участка',target_profit_rg_1)
print('Предсказанная прибыль со второго участка',predicted_profit_rg_2)
print('Фактическая прибыль со второго участка',target_profit_rg_2)
print('Предсказанная прибыль с третьего участка',predicted_profit_rg_3)
print('Фактическая прибыль с третьего участка',target_profit_rg_3)
# Out:
# Предсказанная прибыль с первого участка 3996048877.4651318
# Фактическая прибыль с первого участка 6510947580.318813
# Предсказанная прибыль со второго участка 2487389134.579481
# Фактическая прибыль со второго участка 2415086696.681511
# Предсказанная прибыль с третьего участка 3422406337.1485863
# Фактическая прибыль с третьего участка 6930084424.225573

# %% [markdown]
# Как видно модель сильно ошибается в первом и третьем регионе, во втором предсказание получается довольно точным

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 И размер ошибки в каждом регионе это подтверждает.
# </div>

# %% [markdown]
# <font size=8> Расчёт рисков <font>

# %%
def revenue(target, probs, count):
    probs_sorted = pd.Series(probs).sort_values(ascending=False)
    selected = target[probs_sorted.index][:count]
    return (450000 * sum(selected) - BUDGET)

def bootstrap(target, predictions):
    state = np.random.RandomState(12345)
    target = target.reset_index(drop=True)
    predictions = pd.Series(predictions)
    values = []
    counter = 0
    
    for i in range(1000):
        target_subsample = target.sample(n=COUNT_OF_WELLS, replace=True, random_state=state)
        probs_subsample = predictions[target_subsample.index]
        income = revenue(target_subsample, probs_subsample, COUNT_OF_SELECTED_WELLS)
        if income < 0: 
            counter += 1
        values.append(income)
    values = pd.Series(values)
    lower = values.quantile(0.025)
    upper = values.quantile(0.975)
    mean_values = values.mean()
    return (mean_values, counter / len(values), lower, upper)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Отлично, что при семплировании данных устанавливаешь `replace = True`, это необходимо чтобы наблюдение в выборку попало несколько раз, что позволяет добиться независимости при каждом выборе, иначе вероятность достать элемент из выборки будет с каждым разом увеличиваться. Чем больше размер подвыборки, тем выраженнее будет зависимость, поэтому без возврата не удастся получить разнообразные варианты, а подвыборку бОльшего размера вообще не получить.
#
# Почему именно так. Вспомним, что выборка - это некоторое представление о генеральной совокупности, ее часть. Значит, что где-то в регионе существуют и другие потенциальные точки добычи нефти, о которых мы можем не знать, но они являются частью этой генеральной совокупности. В этом случае повторяющиеся наблюдения можно считать разными точками добычи из всей генеральной совокупности с близкими характеристиками.
#
# </div>

# %%
mean_values_1, risk_1, lower_1, upper_1 = bootstrap(target_valid_rg_1, predictions_1)
print('Средняя выручка в регионе 1', mean_values_1)
print(f"Риск убытков в регионе 1: {risk_1 * 100:.1} %")
print(f'Доверительный интервал, в котором лежит значение прибыли в регионе 1 [{lower_1}:{upper_1}]')
# Out:
# Средняя выручка в регионе 1 425938526.9105928
# Риск убытков в регионе 1: 6e+00 %
# Доверительный интервал, в котором лежит значение прибыли в регионе 1 [-102090094.83793645:947976353.3583689]

# %%
mean_values_2, risk_2, lower_2, upper_2 = bootstrap(target_valid_rg_2, predictions_2)
print('Средняя выручка в регионе 2', mean_values_2)
print(f"Риск убытков в регионе 2: {risk_2 * 100:.1} %")
print(f'Доверительный интервал, в котором лежит значение прибыли в регионе 2 [{lower_2}:{upper_2}]')
# Out:
# Средняя выручка в регионе 2 504889204.1629861
# Риск убытков в регионе 2: 0.5 %
# Доверительный интервал, в котором лежит значение прибыли в регионе 2 [110236114.4150764:935744524.9988513]

# %%
mean_values_3, risk_3, lower_3, upper_3 = bootstrap(target_valid_rg_3, predictions_3)
print('Средняя выручка в регионе 3', mean_values_3)
print(f"Риск убытков в регионе 3: {risk_3 * 100:.1} %")
print(f'Доверительный интервал, в котором лежит значение прибыли в регионе 3 [{lower_3}:{upper_3}]')
# Out:
# Средняя выручка в регионе 3 364513755.7642499
# Риск убытков в регионе 3: 1e+01 %
# Доверительный интервал, в котором лежит значение прибыли в регионе 3 [-206168348.38761687:917815465.332082]

# %% [markdown]
# Таким образом, регион 2 имеет самый низкий процент убытков и лучший по RMSE

# %% [markdown]
# <font size=8> Общий вывод: <font>

# %% [markdown]
# Модель линейной регрессии показала лучший результат для второго региона, там была получена самый лучший показатель метрики RMSE. Далее произвели подсчёт предсказанной и реальной прибыли с каждого региона. С помощью техники Bootstrap были посчитаны риски, средняя прибыль и доверительные интервалы. С учётом всех проведенных исследований я бы порекомендовал выбрать регион 1, т.к. там наблюдается минимальный риск убытков.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Абсолютно верный выбор!
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке исполнения
# - [ ]  Выполнен шаг 1: данные подготовлены
# - [ ]  Выполнен шаг 2: модели обучены и проверены
#     - [ ]  Данные корректно разбиты на обучающую и валидационную выборки
#     - [ ]  Модели обучены, предсказания сделаны
#     - [ ]  Предсказания и правильные ответы на валидационной выборке сохранены
#     - [ ]  На экране напечатаны результаты
#     - [ ]  Сделаны выводы
# - [ ]  Выполнен шаг 3: проведена подготовка к расчёту прибыли
#     - [ ]  Для всех ключевых значений созданы константы Python
#     - [ ]  Посчитано минимальное среднее количество продукта в месторождениях региона, достаточное для разработки
#     - [ ]  По предыдущему пункту сделаны выводы
#     - [ ]  Написана функция расчёта прибыли
# - [ ]  Выполнен шаг 4: посчитаны риски и прибыль
#     - [ ]  Проведена процедура *Bootstrap*
#     - [ ]  Все параметры бутстрепа соответствуют условию
#     - [ ]  Найдены все нужные величины
#     - [ ]  Предложен регион для разработки месторождения
#     - [ ]  Выбор региона обоснован

# %% [markdown]
# <div style="background: #cceeaa; padding: 5px; border: 1px solid green; border-radius: 5px;">
# <font color='green'>
#     <b><u>Общий вывод по проекту</u></b>
# <font color='green'><br>
#
#
# Марк, приложено много усилий, ты - молодец! Есть несколько важных моментов, которые я отметила и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Что мне особенно понравилось в твоей работе:**:
#
#
# * Рассчитан средний запас предсказанного сырья для каждого региона.
# * Рассчитан достаточный объём сырья для безубыточной разработки новой скважины.
# * Написана функция для расчёта прибыли.
# * Рассчитаны риски, прибыль и доверительный интервал для каждого региона.
# * Код логичный и понятный.
# * Проект полностью соответствует плану!
#
#
# **На что стоит обратить внимание**:
#
# * Осталось совсем немного поправить, а именно: использовать константы в проекте, добавить вывод, рассчитать средний запас в каждом регионе. Подсказки ты найдешь в моих комментариях.
#
#
#
#
# **Доработка займет у тебя совсем немного времени) Желаю удачи и жду твой проект на повторное ревью!**😉
